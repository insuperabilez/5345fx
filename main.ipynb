# %%
import os
import json
import re
import cv2
import imagehash
import numpy as np
from PIL import Image
from collections import defaultdict
from tqdm import tqdm
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
import multiprocessing
import argparse
import math 


logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')


SAMPLE_RATE = 2.0
HASH_SIZE = 12
MIN_INTRO_DURATION = 7
MAX_ANALYSIS_TIME = 15 * 60
SKIP_START_TIME = 5
MAX_WORKERS = min(6, multiprocessing.cpu_count())
MAX_INTRO_DURATION = 45
DEFAULT_INTRO_START = 5
DEFAULT_INTRO_END = 15
HASH_DISTANCE_THRESHOLD = 6
MIN_MATCH_PERCENTAGE = 0.75
MATCH_SEARCH_WINDOW_SEC = 15


def time_str_to_seconds(time_str: str) -> int:
    parts = list(map(int, time_str.split(':')))
    seconds = 0
    if len(parts) == 3:
        seconds = parts[0] * 3600 + parts[1] * 60 + parts[2]
    elif len(parts) == 2:
        seconds = parts[0] * 60 + parts[1]
    elif len(parts) == 1:
        seconds = parts[0]
    return seconds

def calculate_iou(pred_box: tuple[float, float], gt_box: tuple[float, float]) -> float:
    pred_start, pred_end = pred_box
    gt_start, gt_end = gt_box
    inter_start = max(pred_start, gt_start)
    inter_end = min(pred_end, gt_end)
    inter_duration = max(0, inter_end - inter_start)
    pred_duration = pred_end - pred_start
    gt_duration = gt_end - gt_start
    union_duration = pred_duration + gt_duration - inter_duration
    if union_duration == 0:
        return 1.0 if inter_duration == 0 else 0.0
    return inter_duration / union_duration

def parse_series_info(name: str) -> tuple[str, int]:
    name_lower = name.lower()
    season_match = re.search(r'(\d+)\s*сезон', name_lower)
    season = int(season_match.group(1)) if season_match else 1
    title_match = re.split(r'\s*\.\s*\d+\s*сезон|\s*\.\s*серия', name, flags=re.IGNORECASE)
    title = title_match[0].strip() if title_match else name.strip()
    return title, season

def group_episodes(metadata_path: str, data_root: str) -> dict:
    logging.info("Группировка серий и загрузка ground truth данных...")
    with open(metadata_path, 'r', encoding='utf-8') as f:
        metadata = json.load(f)
    groups = defaultdict(list)
    for video_id, info in metadata.items():
        try:
            title, season = parse_series_info(info['name'])
            video_dir = os.path.join(data_root, video_id)
            video_file = next((os.path.join(video_dir, f) for f in os.listdir(video_dir) if f.endswith('.mp4')), None)
            if video_file:
                gt_start = time_str_to_seconds(info.get('start', '0'))
                gt_end = time_str_to_seconds(info.get('end', '0'))
                if gt_start > gt_end: gt_start, gt_end = gt_end, gt_start
                groups[(title, season)].append({"path": video_file, "gt_start": gt_start, "gt_end": gt_end})
            else:
                logging.warning(f"Видеофайл для ID {video_id} не найден в {video_dir}")
        except Exception as e:
            logging.error(f"Ошибка при обработке метаданных для ID {video_id} ('{info.get('name')}'): {e}")
    return groups

def calculate_hashes_for_video(video_path: str) -> list[tuple[float, imagehash.ImageHash]]:
    hashes = []
    cap = None
    try:
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened(): return []
        video_fps = cap.get(cv2.CAP_PROP_FPS)
        total_duration = cap.get(cv2.CAP_PROP_FRAME_COUNT) / video_fps if video_fps > 0 else 0
        end_time = min(total_duration, SKIP_START_TIME + MAX_ANALYSIS_TIME)
        current_time = SKIP_START_TIME
        while current_time < end_time:
            cap.set(cv2.CAP_PROP_POS_MSEC, int(current_time * 1000))
            ret, frame = cap.read()
            if not ret: break
            pil_img = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            video_hash = imagehash.dhash(pil_img, hash_size=HASH_SIZE)
            hashes.append((current_time, video_hash))
            current_time += 1.0 / SAMPLE_RATE
    except Exception as e:
        logging.error(f"Ошибка при обработке файла {video_path}: {e}")
    finally:
        if cap: cap.release()
    return hashes

def find_best_intro_candidate(all_hashes_data: dict) -> tuple[float | None, float | None]:
    if len(all_hashes_data) < 2: return None, None
    
    sorted_paths = sorted(all_hashes_data.keys(), key=lambda p: len(all_hashes_data[p]))
    ref_path, other_paths = sorted_paths[0], sorted_paths[1:]
    ref_hashes = all_hashes_data[ref_path]
    if not ref_hashes: return None, None

    other_hashes_list = [all_hashes_data[p] for p in other_paths]

    min_series_with_intro = math.ceil(len(all_hashes_data) * MIN_MATCH_PERCENTAGE)
    min_matches_needed = max(1, min_series_with_intro - 1) 

    match_scores = []
    for i, (ts, ref_hash) in enumerate(ref_hashes):
        matches = sum(1 for other_h in other_hashes_list if any(
            (ref_hash - h[1]) <= HASH_DISTANCE_THRESHOLD
            for h in other_h[max(0, i - MATCH_SEARCH_WINDOW_SEC): i + MATCH_SEARCH_WINDOW_SEC + 1]
        ))
        match_scores.append(matches)

    candidates = []
    in_sequence, start_idx = False, 0
    for i, score in enumerate(match_scores):
        is_strong_match = score >= min_matches_needed
        if is_strong_match and not in_sequence:
            in_sequence, start_idx = True, i
        elif not is_strong_match and in_sequence:
            in_sequence = False
            duration_frames = i - start_idx
            if (duration_frames / SAMPLE_RATE) >= MIN_INTRO_DURATION:
                candidates.append({
                    'start_idx': start_idx,
                    'end_idx': i,
                    'duration': duration_frames
                })

    if in_sequence:
        duration_frames = len(match_scores) - start_idx
        if (duration_frames / SAMPLE_RATE) >= MIN_INTRO_DURATION:
            candidates.append({
                'start_idx': start_idx,
                'end_idx': len(match_scores),
                'duration': duration_frames
            })

    if not candidates:
        return None, None

    best_candidate = max(candidates, key=lambda c: c['duration'])
    
    start_time = ref_hashes[best_candidate['start_idx']][0]
    end_time = ref_hashes[best_candidate['end_idx'] - 1][0] + (1.0 / SAMPLE_RATE)
    
    if (end_time - start_time) > MAX_INTRO_DURATION:
        logging.info(f"Найдена слишком длинная заставка ({end_time - start_time:.0f} сек). Обрезается до {MAX_INTRO_DURATION} сек.")
        end_time = start_time + MAX_INTRO_DURATION

    return start_time, end_time


def main(metadata_path, data_root):

    series_groups = group_episodes(metadata_path, data_root)
    logging.info(f"Найдено {len(series_groups)} групп (сериал/сезон) для анализа.")
    
    results = {}
    all_iou_scores = []

    for (title, season), episodes_data in tqdm(series_groups.items()):
        group_key = f"{title} (Сезон {season})"
        logging.info(f"\n--- Анализ группы: {group_key} ({len(episodes_data)} серий) ---")
        
        start_time, end_time = None, None
        
        if len(episodes_data) > 1:
            filepaths = [e['path'] for e in episodes_data]
            all_hashes_data = {}
            with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
                future_to_path = {executor.submit(calculate_hashes_for_video, path): path for path in filepaths}
                for future in tqdm(as_completed(future_to_path), total=len(filepaths), desc=f"Хэширование '{title}'"):
                    all_hashes_data[future_to_path[future]] = future.result()
            
            all_hashes_data = {k: v for k, v in all_hashes_data.items() if v}
            if len(all_hashes_data) >= 2:
                logging.info("Поиск наилучшего кандидата на заставку...")
                start_time, end_time = find_best_intro_candidate(all_hashes_data)

        log_message = ""
        if start_time is None:
            if len(episodes_data) == 1:
                log_message = "Найдена одна серия, применяется правило по умолчанию."
            else:
                log_message = "Общая заставка не найдена алгоритмом, применяется правило по умолчанию."
            logging.info(log_message)
            start_time, end_time = float(DEFAULT_INTRO_START), float(DEFAULT_INTRO_END)
        else:
             duration = end_time - start_time
             log_message = f"Найдена заставка! [{int(start_time // 60):02d}:{int(start_time % 60):02d} - {int(end_time // 60):02d}:{int(end_time % 60):02d}] Длительность: {int(duration)} сек."
             logging.info(log_message)

        group_ious = []
        pred_box = (start_time, end_time)
        for episode in episodes_data:
            gt_box = (episode['gt_start'], episode['gt_end'])
            iou = calculate_iou(pred_box, gt_box)
            group_ious.append(iou)
                
        avg_group_iou = np.mean(group_ious) if group_ious else 0.0
        results[group_key] = {
            "start": f"{int(start_time // 60):02d}:{int(start_time % 60):02d}",
            "end": f"{int(end_time // 60):02d}:{int(end_time % 60):02d}",
            "duration_sec": int(end_time - start_time),
            "avg_iou": avg_group_iou,
            "log": log_message
        }
        all_iou_scores.extend(group_ious)

    print("\n\n" + "="*60)
    print("ИТОГОВЫЕ РЕЗУЛЬТАТЫ")
    print("="*60)
    for group, intro_data in sorted(results.items()):
        print(f"🎬 Сериал: {group}")
        print(f"   🕒 Предсказание:   {intro_data['start']} - {intro_data['end']} (~{intro_data['duration_sec']} сек.)")
        print(f"   📊 Качество (IoU): {intro_data['avg_iou']:.2%}")
    print("="*60)
    if all_iou_scores:
        overall_avg_iou = np.mean(all_iou_scores)
        print(f"\n🏆 ОБЩЕЕ СРЕДНЕЕ КАЧЕСТВО (IoU) ПО ВСЕМ СЕРИЯМ: {overall_avg_iou:.2%}")
    print("="*60)

# %%
if __name__ == "__main__":
    main(metadata_path='D:/vk/data/data/labels.json', data_root='D:/vk/data/data/')
# Out:
# 2025-06-13 13:39:53,262 - INFO - Группировка серий и загрузка ground truth данных...
# 2025-06-13 13:39:53,265 - INFO - Найдено 34 групп (сериал/сезон) для анализа.
#   0%|          | 0/34 [00:00<?, ?it/s]2025-06-13 13:39:53,266 - INFO -
# --- Анализ группы: Баскетс (Сезон 4) (5 серий) ---
# Хэширование 'Баскетс': 100%|██████████| 5/5 [01:24<00:00, 17.00s/it]
# 2025-06-13 13:41:18,248 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:41:18,560 - INFO - Найдена заставка! [00:05 - 00:31] Длительность: 26 сек.
#   3%|▎         | 1/34 [01:25<46:54, 85.30s/it]2025-06-13 13:41:18,561 - INFO -
# --- Анализ группы: Бывaeт и xyжe (Сезон 1) (3 серий) ---
# Хэширование 'Бывaeт и xyжe': 100%|██████████| 3/3 [00:41<00:00, 13.88s/it]
# 2025-06-13 13:42:00,194 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:42:00,355 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
#   6%|▌         | 2/34 [02:07<31:50, 59.71s/it]2025-06-13 13:42:00,356 - INFO -
# --- Анализ группы: Анатомия скандала (Сезон 1) (4 серий) ---
# Хэширование 'Анатомия скандала': 100%|██████████| 4/4 [01:01<00:00, 15.36s/it]
# 2025-06-13 13:43:01,796 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:43:02,035 - INFO - Найдена заставка! [00:05 - 00:22] Длительность: 17 сек.
#   9%|▉         | 3/34 [03:08<31:18, 60.61s/it]2025-06-13 13:43:02,036 - INFO -
# --- Анализ группы: Блеск (Сезон 2) (3 серий) ---
# Хэширование 'Блеск': 100%|██████████| 3/3 [00:44<00:00, 14.72s/it]
# 2025-06-13 13:43:46,214 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:43:46,376 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
#  12%|█▏        | 4/34 [03:53<27:05, 54.19s/it]2025-06-13 13:43:46,377 - INFO -
# --- Анализ группы: Амepикaнcкий вaндaл (Сезон 1) (3 серий) ---
# Хэширование 'Амepикaнcкий вaндaл': 100%|██████████| 3/3 [00:38<00:00, 12.95s/it]
# 2025-06-13 13:44:25,235 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:44:25,394 - INFO - Найдена заставка! [00:21 - 00:41] Длительность: 20 сек.
#  15%|█▍        | 5/34 [04:32<23:32, 48.72s/it]2025-06-13 13:44:25,395 - INFO -
# --- Анализ группы: Бриджертоны (Сезон 3) (4 серий) ---
# Хэширование 'Бриджертоны': 100%|██████████| 4/4 [01:00<00:00, 15.07s/it]
# 2025-06-13 13:45:25,672 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:45:25,912 - INFO - Найдена заставка! [00:05 - 00:25] Длительность: 20 сек.
#  18%|█▊        | 6/34 [05:32<24:36, 52.73s/it]2025-06-13 13:45:25,913 - INFO -
# --- Анализ группы: Бывaeт и xyжe (Сезон 2) (6 серий) ---
# Хэширование 'Бывaeт и xyжe': 100%|██████████| 6/6 [01:19<00:00, 13.23s/it]
# 2025-06-13 13:46:45,280 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:46:45,682 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
#  21%|██        | 7/34 [06:52<27:42, 61.57s/it]2025-06-13 13:46:45,683 - INFO -
# --- Анализ группы: Агентство Локвуд и компания (Сезон 1) (1 серий) ---
# 2025-06-13 13:46:45,683 - INFO - Найдена одна серия, применяется правило по умолчанию.
# 2025-06-13 13:46:45,684 - INFO -
# --- Анализ группы: Бойцовская ночь: Афера на миллион (Сезон 1) (4 серий) ---
# Хэширование 'Бойцовская ночь: Афера на миллион': 100%|██████████| 4/4 [00:52<00:00, 13.20s/it]
# 2025-06-13 13:47:38,497 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:47:38,738 - INFO - Найдена заставка! [00:07 - 00:15] Длительность: 7 сек.
#  26%|██▋       | 9/34 [07:45<18:36, 44.65s/it]2025-06-13 13:47:38,740 - INFO -
# --- Анализ группы: Бeвepли-Xиллз 90210 (Сезон 5) (1 серий) ---
# 2025-06-13 13:47:38,740 - INFO - Найдена одна серия, применяется правило по умолчанию.
# 2025-06-13 13:47:38,740 - INFO -
# --- Анализ группы: Баскетс (Сезон 3) (7 серий) ---
# Хэширование 'Баскетс': 100%|██████████| 7/7 [02:00<00:00, 17.27s/it]
# 2025-06-13 13:49:39,615 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:49:40,082 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
#  32%|███▏      | 11/34 [09:46<19:37, 51.19s/it]2025-06-13 13:49:40,083 - INFO -
# --- Анализ группы: Белые линии (Сезон 1) (4 серий) ---
# Хэширование 'Белые линии': 100%|██████████| 4/4 [00:57<00:00, 14.31s/it]
# 2025-06-13 13:50:37,312 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:50:37,542 - INFO - Найдена заставка! [00:05 - 00:22] Длительность: 17 сек.
#  35%|███▌      | 12/34 [10:44<19:17, 52.60s/it]2025-06-13 13:50:37,543 - INFO -
# --- Анализ группы: Берлин. 8 серия (финал) (Сезон 1) (1 серий) ---
# 2025-06-13 13:50:37,543 - INFO - Найдена одна серия, применяется правило по умолчанию.
# 2025-06-13 13:50:37,544 - INFO -
# --- Анализ группы: Блaгиe знaмeния (Сезон 1) (1 серий) ---
# 2025-06-13 13:50:37,544 - INFO - Найдена одна серия, применяется правило по умолчанию.
# 2025-06-13 13:50:37,544 - INFO -
# --- Анализ группы: Баскетс (Сезон 1) (1 серий) ---
# 2025-06-13 13:50:37,545 - INFO - Найдена одна серия, применяется правило по умолчанию.
# 2025-06-13 13:50:37,545 - INFO -
# --- Анализ группы: Блеск (Сезон 1) (7 серий) ---
# Хэширование 'Блеск': 100%|██████████| 7/7 [01:47<00:00, 15.39s/it]
# 2025-06-13 13:52:25,249 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:52:25,729 - INFO - Найдена заставка! [00:05 - 00:16] Длительность: 11 сек.
#  47%|████▋     | 16/34 [12:32<11:27, 38.21s/it]2025-06-13 13:52:25,730 - INFO -
# --- Анализ группы: Архив 81 (Сезон 1) (3 серий) ---
# Хэширование 'Архив 81': 100%|██████████| 3/3 [00:47<00:00, 15.93s/it]
# 2025-06-13 13:53:13,544 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:53:13,708 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
#  50%|█████     | 17/34 [13:20<11:17, 39.84s/it]2025-06-13 13:53:13,709 - INFO -
# --- Анализ группы: Баскетс (Сезон 2) (6 серий) ---
# Хэширование 'Баскетс': 100%|██████████| 6/6 [01:40<00:00, 16.72s/it]
# 2025-06-13 13:54:54,037 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:54:54,425 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
#  53%|█████▎    | 18/34 [15:01<13:45, 51.60s/it]2025-06-13 13:54:54,426 - INFO -
# --- Анализ группы: Букмекер (Сезон 1) (2 серий) ---
# Хэширование 'Букмекер': 100%|██████████| 2/2 [00:32<00:00, 16.50s/it]
# 2025-06-13 13:55:27,425 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:55:27,507 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
#  56%|█████▌    | 19/34 [15:34<11:53, 47.59s/it]2025-06-13 13:55:27,508 - INFO -
# --- Анализ группы: 3вeздный пyть: Пикap (Сезон 3) (1 серий) ---
# 2025-06-13 13:55:27,508 - INFO - Найдена одна серия, применяется правило по умолчанию.
# 2025-06-13 13:55:27,509 - INFO -
# --- Анализ группы: Бодкин (Сезон 1) (5 серий) ---
# Хэширование 'Бодкин': 100%|██████████| 5/5 [01:10<00:00, 14.10s/it]
# 2025-06-13 13:56:37,991 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:56:38,298 - INFO - Найдена заставка! [00:05 - 00:19] Длительность: 14 сек.
#  62%|██████▏   | 21/34 [16:45<09:18, 42.94s/it]2025-06-13 13:56:38,299 - INFO -
# --- Анализ группы: Бриджертоны (Сезон 2) (2 серий) ---
# Хэширование 'Бриджертоны': 100%|██████████| 2/2 [00:31<00:00, 15.85s/it]
# 2025-06-13 13:57:10,005 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:57:10,082 - INFO - Найдена заставка! [00:05 - 00:25] Длительность: 20 сек.
#  65%|██████▍   | 22/34 [17:16<08:06, 40.55s/it]2025-06-13 13:57:10,082 - INFO -
# --- Анализ группы: Букмекер (Сезон 2) (2 серий) ---
# Хэширование 'Букмекер': 100%|██████████| 2/2 [00:29<00:00, 14.53s/it]
# 2025-06-13 13:57:39,144 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:57:39,223 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
#  68%|██████▊   | 23/34 [17:45<06:56, 37.87s/it]2025-06-13 13:57:39,224 - INFO -
# --- Анализ группы: Амepикaнcкий вaндaл (Сезон 2) (1 серий) ---
# 2025-06-13 13:57:39,224 - INFO - Найдена одна серия, применяется правило по умолчанию.
# 2025-06-13 13:57:39,225 - INFO -
# --- Анализ группы: Берлин. 1 серия (Сезон 1) (1 серий) ---
# 2025-06-13 13:57:39,225 - INFO - Найдена одна серия, применяется правило по умолчанию.
# 2025-06-13 13:57:39,226 - INFO -
# --- Анализ группы: Американские Истории Ужасов (Сезон 3) (2 серий) ---
# Хэширование 'Американские Истории Ужасов': 100%|██████████| 2/2 [00:27<00:00, 13.63s/it]
# 2025-06-13 13:58:06,491 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 13:58:06,570 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
#  76%|███████▋  | 26/34 [18:13<03:07, 23.46s/it]2025-06-13 13:58:06,571 - INFO -
# --- Анализ группы: 24 часа (Сезон 2) (8 серий) ---
# Хэширование '24 часа': 100%|██████████| 8/8 [03:41<00:00, 27.70s/it]
# 2025-06-13 14:01:48,155 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 14:01:48,691 - INFO - Найдена заставка! [00:12 - 00:19] Длительность: 7 сек.
#  79%|███████▉  | 27/34 [21:55<07:12, 61.74s/it]2025-06-13 14:01:48,692 - INFO -
# --- Анализ группы: 24 часа (Сезон 8) (6 серий) ---
# Хэширование '24 часа': 100%|██████████| 6/6 [03:05<00:00, 30.89s/it]
# 2025-06-13 14:04:54,064 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 14:04:54,465 - INFO - Найдена заставка! [00:05 - 00:18] Длительность: 13 сек.
#  82%|████████▏ | 28/34 [25:01<08:51, 88.51s/it]2025-06-13 14:04:54,466 - INFO -
# --- Анализ группы: 24 часа (Сезон 3) (4 серий) ---
# Хэширование '24 часа': 100%|██████████| 4/4 [01:42<00:00, 25.65s/it]
# 2025-06-13 14:06:37,070 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 14:06:37,304 - INFO - Найдена заставка! [00:05 - 00:17] Длительность: 12 сек.
#  85%|████████▌ | 29/34 [26:44<07:39, 91.88s/it]2025-06-13 14:06:37,305 - INFO -
# --- Анализ группы: 24 часа (Сезон 5) (3 серий) ---
# Хэширование '24 часа': 100%|██████████| 3/3 [01:30<00:00, 30.11s/it]
# 2025-06-13 14:08:07,641 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 14:08:07,802 - INFO - Найдена заставка! [00:05 - 00:18] Длительность: 13 сек.
#  88%|████████▊ | 30/34 [28:14<06:06, 91.53s/it]2025-06-13 14:08:07,803 - INFO -
# --- Анализ группы: 24 часа (Сезон 1) (1 серий) ---
# 2025-06-13 14:08:07,803 - INFO - Найдена одна серия, применяется правило по умолчанию.
# 2025-06-13 14:08:07,804 - INFO -
# --- Анализ группы: 24 часа (Сезон 4) (2 серий) ---
# Хэширование '24 часа': 100%|██████████| 2/2 [00:46<00:00, 23.40s/it]
# 2025-06-13 14:08:54,602 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 14:08:54,684 - INFO - Найдена заставка! [02:12 - 02:19] Длительность: 7 сек.
#  94%|█████████▍| 32/34 [29:01<02:06, 63.04s/it]2025-06-13 14:08:54,685 - INFO -
# --- Анализ группы: 24 часа (Сезон 7) (3 серий) ---
# Хэширование '24 часа': 100%|██████████| 3/3 [01:14<00:00, 24.77s/it]
# 2025-06-13 14:10:08,989 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 14:10:09,150 - INFO - Найдена заставка! [00:05 - 00:19] Длительность: 14 сек.
#  97%|█████████▋| 33/34 [30:15<01:05, 65.67s/it]2025-06-13 14:10:09,151 - INFO -
# --- Анализ группы: 24 часа (Сезон 6) (3 серий) ---
# Хэширование '24 часа': 100%|██████████| 3/3 [01:29<00:00, 29.68s/it]
# 2025-06-13 14:11:38,198 - INFO - Поиск наилучшего кандидата на заставку...
# 2025-06-13 14:11:38,362 - INFO - Общая заставка не найдена алгоритмом, применяется правило по умолчанию.
# 100%|██████████| 34/34 [31:45<00:00, 56.03s/it]
# ============================================================
# ИТОГОВЫЕ РЕЗУЛЬТАТЫ
# ============================================================
# 🎬 Сериал: 24 часа (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 100.00%
# 🎬 Сериал: 24 часа (Сезон 2)
#    🕒 Предсказание:   00:12 - 00:19 (~7 сек.)
#    📊 Качество (IoU): 25.89%
# 🎬 Сериал: 24 часа (Сезон 3)
#    🕒 Предсказание:   00:05 - 00:17 (~12 сек.)
#    📊 Качество (IoU): 85.42%
# 🎬 Сериал: 24 часа (Сезон 4)
#    🕒 Предсказание:   02:12 - 02:19 (~7 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: 24 часа (Сезон 5)
#    🕒 Предсказание:   00:05 - 00:18 (~13 сек.)
#    📊 Качество (IoU): 76.54%
# 🎬 Сериал: 24 часа (Сезон 6)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 66.67%
# 🎬 Сериал: 24 часа (Сезон 7)
#    🕒 Предсказание:   00:05 - 00:19 (~14 сек.)
#    📊 Качество (IoU): 75.86%
# 🎬 Сериал: 24 часа (Сезон 8)
#    🕒 Предсказание:   00:05 - 00:18 (~13 сек.)
#    📊 Качество (IoU): 75.31%
# 🎬 Сериал: 3вeздный пyть: Пикap (Сезон 3)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Агентство Локвуд и компания (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Амepикaнcкий вaндaл (Сезон 1)
#    🕒 Предсказание:   00:21 - 00:41 (~20 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Амepикaнcкий вaндaл (Сезон 2)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Американские Истории Ужасов (Сезон 3)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Анатомия скандала (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:22 (~17 сек.)
#    📊 Качество (IoU): 44.29%
# 🎬 Сериал: Архив 81 (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Бeвepли-Xиллз 90210 (Сезон 5)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Баскетс (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 20.00%
# 🎬 Сериал: Баскетс (Сезон 2)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Баскетс (Сезон 3)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Баскетс (Сезон 4)
#    🕒 Предсказание:   00:05 - 00:31 (~26 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Белые линии (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:22 (~17 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Берлин. 1 серия (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Берлин. 8 серия (финал) (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Блaгиe знaмeния (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.88%
# 🎬 Сериал: Блеск (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:16 (~11 сек.)
#    📊 Качество (IoU): 0.36%
# 🎬 Сериал: Блеск (Сезон 2)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Бодкин (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:19 (~14 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Бойцовская ночь: Афера на миллион (Сезон 1)
#    🕒 Предсказание:   00:07 - 00:15 (~7 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Бриджертоны (Сезон 2)
#    🕒 Предсказание:   00:05 - 00:25 (~20 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Бриджертоны (Сезон 3)
#    🕒 Предсказание:   00:05 - 00:25 (~20 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Букмекер (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Букмекер (Сезон 2)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 0.00%
# 🎬 Сериал: Бывaeт и xyжe (Сезон 1)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 40.00%
# 🎬 Сериал: Бывaeт и xyжe (Сезон 2)
#    🕒 Предсказание:   00:05 - 00:15 (~10 сек.)
#    📊 Качество (IoU): 35.00%
# ============================================================
#
# 🏆 ОБЩЕЕ СРЕДНЕЕ КАЧЕСТВО (IoU) ПО ВСЕМ СЕРИЯМ: 20.80%
# ============================================================
